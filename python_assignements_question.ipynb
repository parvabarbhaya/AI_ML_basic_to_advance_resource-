# %%
# 1. Write a python program to add two numbers.  
a,b = 12,34
print(a+b)
# Out:
# 46

# %%
# 2. Write a python program to find quotient and remainder.  
a,b = int(input("enter number")),int(input("enter number"))

print(f" {a/b} and for the remainder {a%b}")
# Out:
#  1.25 and for the remainder 1

# %%
# 3. Write a python program to find type of objects in your system.  
a = eval(input("Enter a number"))
print(type(a))
# Out:
# <class 'int'>

# %%
# 4. Write a python program to read two numbers and display the greatest number. 
a,b = int(input("enter number")),int(input("enter number"))
print(max(a,b))
# Out:
# 9

# %%
# 5.Write a python program to check whether number is even or odd.  

a = int(input("Enter num:"))
if a%2 == 0:
    print(a)
    print("The number  is even")
else:
    print(a)
    print("The number is odd")
# Out:
# 9
# The number is odd

# %%
# 6 Write a python program to check whether a character is vowel or consonan 
a = str(input("Enter a letter:"))
wovel_lib = ["a","e","i","o","u"]
for i in wovel_lib:
    if i in a :
        print("Is a wovel")
        break
    else:
        print("Not an wovel")
        break
# Out:
# Not an wovel

# %%
#7. Write a python program to find largest number among three numbers.
lis = [1,2,4]
print(max(lis))
# Out:
# 4

# %%
#  Q8 Write a python program to find all roots of a quadratic equation.
# quadratic Equation is: ax2 + bx + c = 0

# %%
#Q9 Write a python program to calculate sum of natural numbers.

nums = [1,2,4,65,7,8,2,332,5,4657,232344,64]
print(sum(nums))
# Out:
# 237491

# %%
# 10. Write a python program to check leap year.
year = int(input("Enter an year"))

if (year % 4 ==0 and year %100 != 0) or (year % 400 == 0):
    print(f"{year} is a leap year")
else:
    print(f"{year} is not a leap year")
# Out:
# 2024 is a leap year
